# %%
import pandas as pd

# %%
df = pd.read_csv("pre-processing.csv")
df
# Out:
#       Date  Rented Bike Count  Hour  Temperature(Celsius)  Humidity(%)  \
# 0        1                254     0                  -5.2           37
# 1        1                204     1                  -5.5           38
# 2        1                173     2                  -6.0           39
# 3        1                107     3                  -6.2           40
# 4        1                 78     4                  -6.0           36
# ...    ...                ...   ...                   ...          ...
# 8755   365               1003    19                   4.2           34
# 8756   365                764    20                   3.4           37
# 8757   365                694    21                   2.6           39
# 8758   365                712    22                   2.1           41
# 8759   365                584    23                   1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(Celsius)  \
# 0                  2.2              2000                           -17.6
# 1                  0.8              2000                           -17.6
# 2                  1.0              2000                           -17.7
# 3                  0.9              2000                           -17.6
# 4                  2.3              2000                           -18.6
# ...                ...               ...                             ...
# 8755               2.6              1894                           -10.3
# 8756               2.3              2000                            -9.9
# 8757               0.3              1968                            -9.9
# 8758               1.0              1859                            -9.8
# 8759               1.3              1909                            -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Seasons  Holiday  Functioning Day
# 0                         0.0           0.0        3        0                1
# 1                         0.0           0.0        3        0                1
# 2                         0.0           0.0        3        0                1
# 3                         0.0           0.0        3        0                1
# 4                         0.0           0.0        3        0                1
# ...                       ...           ...      ...      ...              ...
# 8755                      0.0           0.0        2        0                1
# 8756                      0.0           0.0        2        0                1
# 8757                      0.0           0.0        2        0                1
# 8758                      0.0           0.0        2        0                1
# 8759                      0.0           0.0        2        0                1
#
# [8760 rows x 13 columns]

# %%
x = df.drop(['Rented Bike Count'],axis=1)
x
# Out:
#       Date  Hour  Temperature(Celsius)  Humidity(%)  Wind speed (m/s)  \
# 0        1     0                  -5.2           37               2.2
# 1        1     1                  -5.5           38               0.8
# 2        1     2                  -6.0           39               1.0
# 3        1     3                  -6.2           40               0.9
# 4        1     4                  -6.0           36               2.3
# ...    ...   ...                   ...          ...               ...
# 8755   365    19                   4.2           34               2.6
# 8756   365    20                   3.4           37               2.3
# 8757   365    21                   2.6           39               0.3
# 8758   365    22                   2.1           41               1.0
# 8759   365    23                   1.9           43               1.3
#
#       Visibility (10m)  Dew point temperature(Celsius)  \
# 0                 2000                           -17.6
# 1                 2000                           -17.6
# 2                 2000                           -17.7
# 3                 2000                           -17.6
# 4                 2000                           -18.6
# ...                ...                             ...
# 8755              1894                           -10.3
# 8756              2000                            -9.9
# 8757              1968                            -9.9
# 8758              1859                            -9.8
# 8759              1909                            -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Seasons  Holiday  Functioning Day
# 0                         0.0           0.0        3        0                1
# 1                         0.0           0.0        3        0                1
# 2                         0.0           0.0        3        0                1
# 3                         0.0           0.0        3        0                1
# 4                         0.0           0.0        3        0                1
# ...                       ...           ...      ...      ...              ...
# 8755                      0.0           0.0        2        0                1
# 8756                      0.0           0.0        2        0                1
# 8757                      0.0           0.0        2        0                1
# 8758                      0.0           0.0        2        0                1
# 8759                      0.0           0.0        2        0                1
#
# [8760 rows x 12 columns]

# %%
y = df['Rented Bike Count'].values
y
# Out:
# array([254, 204, 173, ..., 694, 712, 584])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %%
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
model = make_pipeline(StandardScaler(), SVR(C=1.0, epsilon=0.2))
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svr', SVR(epsilon=0.2))])

# %%
res_text = model.predict(X_test)
res_text
# Out:
# array([463.51265665, 726.68321604, 728.17775586, ..., 623.44949166,
#        740.43583332, 461.66764183])

# %%
model.score(X_train,y_train)
# Out:
# 0.3998307352112629

# %%
model.score(X_test,y_test)
# Out:
# 0.39199578833762583

# %%
from sklearn.metrics import mean_absolute_error
MAE = mean_absolute_error(y_test, res_text)
MAE
# Out:
# 338.6548940543584

# %%
from sklearn.metrics import mean_squared_error
RMSE = mean_squared_error(y_test, res_text, squared=False)
RMSE
# Out:
# 501.28077392689625

# %%
from sklearn.metrics import mean_absolute_percentage_error
MAPE = mean_absolute_percentage_error(y_test, res_text)
MAPE
# Out:
# 5.537774266527934e+16
